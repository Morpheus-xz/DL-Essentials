# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
model = models.Sequential()

model.add(layers.Input(shape=(32,32,3)))

model.add(layers.Conv2D(32,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Flatten())

model.add(layers.Dense(64,activation='relu'))

model.add(layers.Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=10)

print("\nLoss and Accuracy after each epoch:\n")

for i in range(10):
    print("Epoch", i+1)
    print("Loss:", history.history['loss'][i])
    print("Accuracy:", history.history['accuracy'][i])
    print("---------------------------")
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 64s 40ms/step - accuracy: 0.3611 - loss: 1.7442
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 62s 40ms/step - accuracy: 0.5888 - loss: 1.1690
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 61s 39ms/step - accuracy: 0.6495 - loss: 1.0127
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 40ms/step - accuracy: 0.6843 - loss: 0.9106
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 39ms/step - accuracy: 0.7087 - loss: 0.8400
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 61s 39ms/step - accuracy: 0.7283 - loss: 0.7797
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 66s 42ms/step - accuracy: 0.7469 - loss: 0.7343
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 62s 40ms/step - accuracy: 0.7584 - loss: 0.6897
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 39ms/step - accuracy: 0.7770 - loss: 0.6396
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 62s 40ms/step - accuracy: 0.7866 - loss: 0.6134
#
# Loss and Accuracy after each epoch:
#
# Epoch 1
# Loss: 1.50065016746521
# Accuracy: 0.4609200060367584
# ---------------------------
# Epoch 2
# Loss: 1.1312336921691895
# Accuracy: 0.6034799814224243
# ---------------------------
# Epoch 3
# Loss: 1.0034922361373901
# Accuracy: 0.6507800221443176
# ---------------------------
# Epoch 4
# Loss: 0.913630485534668
# Accuracy: 0.6824600100517273
# ---------------------------
# Epoch 5
# Loss: 0.8440431952476501
# Accuracy: 0.7078800201416016
# ---------------------------
# Epoch 6
# Loss: 0.7887238264083862
# Accuracy: 0.7259200215339661
# ---------------------------
# Epoch 7
# Loss: 0.7422022819519043
# Accuracy: 0.7438600063323975
# ---------------------------
# Epoch 8
# Loss: 0.7023705244064331
# Accuracy: 0.7545199990272522
# ---------------------------
# Epoch 9
# Loss: 0.6601200699806213
# Accuracy: 0.7701399922370911
# ---------------------------
# Epoch 10
# Loss: 0.6253113150596619
# Accuracy: 0.7826399803161621
# ---------------------------

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6993 - loss: 0.9176
# Test Accuracy: 0.6940000057220459
